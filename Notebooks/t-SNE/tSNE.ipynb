# %%
import numpy as np
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt

import sys

# %matplotlib inline

# %%
sys.stdout=open("external_file.txt","w")
print ("this is a log message")

# %%
print("this is a log message 2")

# %%
sys.stdout.close()

# %%
a=1

# %%
sys.stdout=open("external_file.txt","w")
n = 5000
X = np.random.normal(0,1,size=(n,10))
Y = np.random.binomial(2,.5,n)
Z = TSNE(n_components=2, verbose=1).fit_transform(X)
Z.shape
# Out:
# (5000, 2)

# %%
plt.scatter(Z[:,0],Z[:,1], c=Y )

# %%
np.savetxt("Z.csv", Z, delimiter=",")

# %%
import io
from contextlib import redirect_stdout

f = io.StringIO()
with redirect_stdout(f):
    print('foobar')
    print(12)
print('Got stdout: "{0}"'.format(f.getvalue()))

# %%
f.

# %% [markdown]
# ## Plot results

# %%
import pandas as pd
import seaborn as sns

# %%
Z = np.load("mad1000/Z.npy")
labels = np.load("mad1000/labels.npy")

# %%
fig,ax = plt.subplots(figsize=(5,5))
#ax.scatter(Z[:,0],Z[:,1], c=labels, cmap='viridis')
ax.scatter(Z[:,0],Z[:,1])

# %%
df = pd.concat([
    pd.DataFrame(Z, columns=["X1","X2"]),
    pd.DataFrame(labels, columns=["label"])
],axis=1)

# %%
from ggplot import *

# %%
chart = ggplot( df, aes(x='X1', y='X2', color='label') ) \
        + geom_point(size=70, alpha=.2) \
        + ggtitle("t-SNE using 1000 features with largest MAD") \
        + theme_bw()
chart.save("mad1000/t-SNE.pdf")

# %%
sns.scatterplot(x='X1',y='X2',hue='label',data=data)

# %%
sns.scatterplot(x='X1',y='X2',hue='label',data=data)

# %%
import ggplot
# Out:
# //anaconda/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,

# %%
from pandas import TimeSeries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-46-3b7fb03d82a3> in <module>()
# ----> 1 from pandas import TimeSeries
#
# ImportError: cannot import name 'TimeSeries'
